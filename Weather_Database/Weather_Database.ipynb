# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8296fd168477c9dc72c2cc0c229be3fb

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
import json

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | barrow
# Processing Record 2 of Set 16 | bulgan
# Processing Record 3 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 16 | jamestown
# Processing Record 5 of Set 16 | laredo
# Processing Record 6 of Set 16 | kapaa
# Processing Record 7 of Set 16 | porto walter
# Processing Record 8 of Set 16 | punta arenas
# Processing Record 9 of Set 16 | omboue
# Processing Record 10 of Set 16 | prince rupert
# Processing Record 11 of Set 16 | hermanus
# Processing Record 12 of Set 16 | busselton
# Processing Record 13 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 16 | langa
# Processing Record 15 of Set 16 | zhigansk
# Processing Record 16 of Set 16 | aklavik
# Processing Record 17 of Set 16 | ushuaia
# Processing Record 18 of Set 16 | iqaluit
# Processing Record 19 of Set 16 | east london
# Processing Record 20 of Set 16 | ponta do sol
# Processing Record 21 of Set 16 | sarkand
# Processing Record 22 of Set 16 | mataura
# Processing Record 23 of Set 16 | rikitea
# Processing Record 24 of Set 16 | lorengau
# Processing Record 25 of Set 16 | cape town
# Processing Record 26 of Set 16 | port hardy
# Processing Record 27 of Set 16 | bredasdorp
# Processing Record 28 of Set 16 | deder
# Processing Record 29 of Set 16 | waverley
# Processing Record 30 of Set 16 | toktogul
# Processing Record 31 of Set 16 | qaanaaq
# Processing Record 32 of Set 16 | kudahuvadhoo
# Processing Record 33 of Set 16 | nakamura
# Processing Record 34 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 16 | tasiilaq
# Processing Record 36 of Set 16 | arraial do cabo
# Processing Record 37 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 16 | laguna
# Processing Record 39 of Set 16 | khatanga
# Processing Record 40 of Set 16 | sakaiminato
# Processing Record 41 of Set 16 | klaksvik
# Processing Record 42 of Set 16 | wuwei
# Processing Record 43 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 16 | ribeira grande
# Processing Record 45 of Set 16 | ust-tsilma
# Processing Record 46 of Set 16 | irbeyskoye
# Processing Record 47 of Set 16 | atuona
# Processing Record 48 of Set 16 | port alfred
# Processing Record 49 of Set 16 | roura
# Processing Record 50 of Set 16 | husavik
# Processing Record 1 of Set 17 | springbok
# Processing Record 2 of Set 17 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 17 | nanakuli
# Processing Record 4 of Set 17 | carnarvon
# Processing Record 5 of Set 17 | butaritari
# Processing Record 6 of Set 17 | esperance
# Processing Record 7 of Set 17 | safaga
# Processing Record 8 of Set 17 | yellowknife
# Processing Record 9 of Set 17 | hobart
# Processing Record 10 of Set 17 | awjilah
# Processing Record 11 of Set 17 | lagoa
# Processing Record 12 of Set 17 | bubaque
# Processing Record 13 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 17 | korla
# Processing Record 15 of Set 17 | salamiyah
# Processing Record 16 of Set 17 | saint-philippe
# Processing Record 17 of Set 17 | carutapera
# Processing Record 18 of Set 17 | yulara
# Processing Record 19 of Set 17 | evensk
# Processing Record 20 of Set 17 | buraydah
# Processing Record 21 of Set 17 | bluff
# Processing Record 22 of Set 17 | reinosa
# Processing Record 23 of Set 17 | jacksonville
# Processing Record 24 of Set 17 | rio grande
# Processing Record 25 of Set 17 | fairbanks
# Processing Record 26 of Set 17 | severo-kurilsk
# Processing Record 27 of Set 17 | vestmannaeyjar
# Processing Record 28 of Set 17 | nikolskoye
# Processing Record 29 of Set 17 | vaini
# Processing Record 30 of Set 17 | georgetown
# Processing Record 31 of Set 17 | albany
# Processing Record 32 of Set 17 | geraldton
# Processing Record 33 of Set 17 | sulechow
# Processing Record 34 of Set 17 | santa cruz de tenerife
# Processing Record 35 of Set 17 | dikson
# Processing Record 36 of Set 17 | port macquarie
# Processing Record 37 of Set 17 | hilo
# Processing Record 38 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 17 | san quintin
# Processing Record 40 of Set 17 | ust-kuyga
# Processing Record 41 of Set 17 | kharian
# Processing Record 42 of Set 17 | thompson
# Processing Record 43 of Set 17 | baherden
# Processing Record 44 of Set 17 | balaipungut
# Processing Record 45 of Set 17 | sujiatun
# Processing Record 46 of Set 17 | hengshui
# Processing Record 47 of Set 17 | hillsborough
# Processing Record 48 of Set 17 | kloulklubed
# Processing Record 49 of Set 17 | baghdad
# Processing Record 50 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 18 | bhawanipatna
# Processing Record 2 of Set 18 | gobo
# Processing Record 3 of Set 18 | broome
# Processing Record 4 of Set 18 | saldanha
# Processing Record 5 of Set 18 | te anau
# Processing Record 6 of Set 18 | hofn
# Processing Record 7 of Set 18 | chuy
# Processing Record 8 of Set 18 | coromandel
# Processing Record 9 of Set 18 | lebu
# Processing Record 10 of Set 18 | samus
# Processing Record 11 of Set 18 | majalgaon
# Processing Record 12 of Set 18 | katsuura
# Processing Record 13 of Set 18 | eirunepe
# Processing Record 14 of Set 18 | faanui
# Processing Record 15 of Set 18 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 18 | san patricio
# Processing Record 17 of Set 18 | entre rios
# Processing Record 18 of Set 18 | terrace
# Processing Record 19 of Set 18 | tuktoyaktuk
# Processing Record 20 of Set 18 | montelibano
# Processing Record 21 of Set 18 | sola
# Processing Record 22 of Set 18 | codrington
# Processing Record 23 of Set 18 | port elizabeth
# Processing Record 24 of Set 18 | salalah
# Processing Record 25 of Set 18 | great falls
# Processing Record 26 of Set 18 | sur
# Processing Record 27 of Set 18 | kruisfontein
# Processing Record 28 of Set 18 | sao filipe
# Processing Record 29 of Set 18 | avarua
# Processing Record 30 of Set 18 | najran
# Processing Record 31 of Set 18 | constitucion
# Processing Record 32 of Set 18 | vao
# Processing Record 33 of Set 18 | bilibino
# Processing Record 34 of Set 18 | tucuman
# Processing Record 35 of Set 18 | asau
# Processing Record 36 of Set 18 | simao
# Processing Record 37 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 18 | upernavik
# Processing Record 39 of Set 18 | chokurdakh
# Processing Record 40 of Set 18 | broken hill
# Processing Record 41 of Set 18 | bengkulu
# Processing Record 42 of Set 18 | bollnas
# Processing Record 43 of Set 18 | tinogboc
# Processing Record 44 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 18 | umm kaddadah
# Processing Record 46 of Set 18 | coquimbo
# Processing Record 47 of Set 18 | hasaki
# Processing Record 48 of Set 18 | pingyi
# Processing Record 49 of Set 18 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 18 | dingle
# Processing Record 1 of Set 19 | wewak
# Processing Record 2 of Set 19 | meulaboh
# Processing Record 3 of Set 19 | avera
# Processing Record 4 of Set 19 | new norfolk
# Processing Record 5 of Set 19 | pevek
# Processing Record 6 of Set 19 | primorka
# Processing Record 7 of Set 19 | mantua
# Processing Record 8 of Set 19 | ornskoldsvik
# Processing Record 9 of Set 19 | tazovskiy
# Processing Record 10 of Set 19 | denpasar
# Processing Record 11 of Set 19 | slyudyanka
# Processing Record 12 of Set 19 | bethel
# Processing Record 13 of Set 19 | talnakh
# Processing Record 14 of Set 19 | port hedland
# Processing Record 15 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 19 | hithadhoo
# Processing Record 17 of Set 19 | suez
# Processing Record 18 of Set 19 | aksu
# Processing Record 19 of Set 19 | marzuq
# Processing Record 20 of Set 19 | cayenne
# Processing Record 21 of Set 19 | charters towers
# Processing Record 22 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 19 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 19 | mehamn
# Processing Record 25 of Set 19 | karratha
# Processing Record 26 of Set 19 | odessa
# Processing Record 27 of Set 19 | san jose
# Processing Record 28 of Set 19 | saint anthony
# Processing Record 29 of Set 19 | sao paulo de olivenca
# Processing Record 30 of Set 19 | kalmunai
# Processing Record 31 of Set 19 | batticaloa
# Processing Record 32 of Set 19 | leningradskiy
# Processing Record 33 of Set 19 | dawei
# Processing Record 34 of Set 19 | port blair
# Processing Record 35 of Set 19 | maraba
# Processing Record 36 of Set 19 | rathdrum
# Processing Record 37 of Set 19 | shingu
# Processing Record 38 of Set 19 | rawson
# Processing Record 39 of Set 19 | cidreira
# Processing Record 40 of Set 19 | kahului
# Processing Record 41 of Set 19 | the valley
# Processing Record 42 of Set 19 | navabad
# City not found. Skipping...
# Processing Record 43 of Set 19 | mananjary
# Processing Record 44 of Set 19 | cherskiy
# Processing Record 45 of Set 19 | mar del plata
# Processing Record 46 of Set 19 | kattivakkam
# Processing Record 47 of Set 19 | kirakira
# Processing Record 48 of Set 19 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 19 | mount gambier
# Processing Record 50 of Set 19 | makakilo city
# Processing Record 1 of Set 20 | linxia
# Processing Record 2 of Set 20 | mahebourg
# Processing Record 3 of Set 20 | bar harbor
# Processing Record 4 of Set 20 | mocuba
# Processing Record 5 of Set 20 | ulaangom
# Processing Record 6 of Set 20 | saskylakh
# Processing Record 7 of Set 20 | puerto ayora
# Processing Record 8 of Set 20 | praia da vitoria
# Processing Record 9 of Set 20 | saucillo
# Processing Record 10 of Set 20 | lerwick
# Processing Record 11 of Set 20 | castro
# Processing Record 12 of Set 20 | portland
# Processing Record 13 of Set 20 | apricena
# Processing Record 14 of Set 20 | nelson bay
# Processing Record 15 of Set 20 | torbay
# Processing Record 16 of Set 20 | airai
# Processing Record 17 of Set 20 | dinsor
# City not found. Skipping...
# Processing Record 18 of Set 20 | manavgat
# Processing Record 19 of Set 20 | harper
# Processing Record 20 of Set 20 | imeni poliny osipenko
# Processing Record 21 of Set 20 | quatre cocos
# Processing Record 22 of Set 20 | kutum
# Processing Record 23 of Set 20 | vanavara
# Processing Record 24 of Set 20 | sulina
# Processing Record 25 of Set 20 | kieta
# Processing Record 26 of Set 20 | raffadali
# Processing Record 27 of Set 20 | thinadhoo
# Processing Record 28 of Set 20 | basti
# Processing Record 29 of Set 20 | hailin
# Processing Record 30 of Set 20 | china
# Processing Record 31 of Set 20 | mubi
# Processing Record 32 of Set 20 | sao jose da coroa grande
# Processing Record 33 of Set 20 | puerto escondido
# Processing Record 34 of Set 20 | vila
# Processing Record 35 of Set 20 | fortuna
# Processing Record 36 of Set 20 | cheremukhovo
# Processing Record 37 of Set 20 | itaituba
# Processing Record 38 of Set 20 | sanmenxia
# Processing Record 39 of Set 20 | narsaq
# Processing Record 40 of Set 20 | lagunas
# Processing Record 41 of Set 20 | longyearbyen
# Processing Record 42 of Set 20 | stillwater
# Processing Record 43 of Set 20 | nuuk
# Processing Record 44 of Set 20 | okaihau
# Processing Record 45 of Set 20 | camacupa
# Processing Record 46 of Set 20 | brae
# Processing Record 47 of Set 20 | ondangwa
# Processing Record 48 of Set 20 | tuatapere
# Processing Record 49 of Set 20 | raudeberg
# Processing Record 50 of Set 20 | launceston
# Processing Record 1 of Set 21 | high level
# Processing Record 2 of Set 21 | laksham
# Processing Record 3 of Set 21 | ahipara
# Processing Record 4 of Set 21 | beringovskiy
# Processing Record 5 of Set 21 | alofi
# Processing Record 6 of Set 21 | lavrentiya
# Processing Record 7 of Set 21 | chimore
# Processing Record 8 of Set 21 | santa cruz
# Processing Record 9 of Set 21 | sarankhola
# Processing Record 10 of Set 21 | upala
# Processing Record 11 of Set 21 | yashkul
# Processing Record 12 of Set 21 | vuktyl
# Processing Record 13 of Set 21 | glendive
# Processing Record 14 of Set 21 | uruzgan
# Processing Record 15 of Set 21 | aden
# Processing Record 16 of Set 21 | clyde river
# Processing Record 17 of Set 21 | sao geraldo do araguaia
# Processing Record 18 of Set 21 | gilgit
# Processing Record 19 of Set 21 | sitka
# Processing Record 20 of Set 21 | lodja
# Processing Record 21 of Set 21 | brownsville
# Processing Record 22 of Set 21 | luderitz
# Processing Record 23 of Set 21 | anloga
# Processing Record 24 of Set 21 | yatou
# Processing Record 25 of Set 21 | guerrero negro
# Processing Record 26 of Set 21 | vanimo
# Processing Record 27 of Set 21 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 21 | dunedin
# Processing Record 29 of Set 21 | mao
# Processing Record 30 of Set 21 | umm lajj
# Processing Record 31 of Set 21 | tarazona
# Processing Record 32 of Set 21 | okahandja
# Processing Record 33 of Set 21 | ostrovnoy
# Processing Record 34 of Set 21 | nikolayevsk-na-amure
# Processing Record 35 of Set 21 | aswan
# Processing Record 36 of Set 21 | caernarfon
# Processing Record 37 of Set 21 | beloha
# Processing Record 38 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 21 | kodiak
# Processing Record 40 of Set 21 | caravelas
# Processing Record 41 of Set 21 | port augusta
# Processing Record 42 of Set 21 | mpika
# Processing Record 43 of Set 21 | bereznik
# Processing Record 44 of Set 21 | kavaratti
# Processing Record 45 of Set 21 | cambridge
# Processing Record 46 of Set 21 | plettenberg bay
# Processing Record 47 of Set 21 | kawalu
# Processing Record 48 of Set 21 | rocha
# Processing Record 49 of Set 21 | tiksi
# Processing Record 50 of Set 21 | omsukchan
# Processing Record 1 of Set 22 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 22 | mnogovershinnyy
# Processing Record 3 of Set 22 | bintulu
# Processing Record 4 of Set 22 | imbituba
# Processing Record 5 of Set 22 | santa maria
# Processing Record 6 of Set 22 | cabadiangan
# Processing Record 7 of Set 22 | arua
# Processing Record 8 of Set 22 | baker city
# Processing Record 9 of Set 22 | acapulco
# Processing Record 10 of Set 22 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 22 | tilichiki
# Processing Record 12 of Set 22 | kaura namoda
# Processing Record 13 of Set 22 | mayya
# Processing Record 14 of Set 22 | upington
# Processing Record 15 of Set 22 | lata
# Processing Record 16 of Set 22 | ryotsu
# Processing Record 17 of Set 22 | cianjur
# Processing Record 18 of Set 22 | machali
# Processing Record 19 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 22 | octeville
# Processing Record 21 of Set 22 | malinovskiy
# Processing Record 22 of Set 22 | gull lake
# Processing Record 23 of Set 22 | cairns
# Processing Record 24 of Set 22 | san angelo
# Processing Record 25 of Set 22 | conceicao do araguaia
# Processing Record 26 of Set 22 | porto de moz
# Processing Record 27 of Set 22 | hualmay
# Processing Record 28 of Set 22 | hamilton
# Processing Record 29 of Set 22 | mchinji
# Processing Record 30 of Set 22 | souillac
# Processing Record 31 of Set 22 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 22 | podgorica
# Processing Record 33 of Set 22 | timoteo
# Processing Record 34 of Set 22 | yataity del norte
# Processing Record 35 of Set 22 | mgandu
# Processing Record 36 of Set 22 | san pedro
# Processing Record 37 of Set 22 | valsamata
# Processing Record 38 of Set 22 | kolaras
# Processing Record 39 of Set 22 | sao joao do piaui
# Processing Record 40 of Set 22 | bambous virieux
# Processing Record 41 of Set 22 | goderich
# Processing Record 42 of Set 22 | gat
# Processing Record 43 of Set 22 | iquitos
# Processing Record 44 of Set 22 | half moon bay
# Processing Record 45 of Set 22 | naryan-mar
# Processing Record 46 of Set 22 | kankaanpaa
# Processing Record 47 of Set 22 | tuy hoa
# Processing Record 48 of Set 22 | havre-saint-pierre
# Processing Record 49 of Set 22 | kataysk
# Processing Record 50 of Set 22 | mzimba
# Processing Record 1 of Set 23 | nanortalik
# Processing Record 2 of Set 23 | gatbo
# Processing Record 3 of Set 23 | chippewa falls
# Processing Record 4 of Set 23 | paamiut
# Processing Record 5 of Set 23 | krasnyy bor
# Processing Record 6 of Set 23 | boyolangu
# Processing Record 7 of Set 23 | provideniya
# Processing Record 8 of Set 23 | mikhaylovka
# Processing Record 9 of Set 23 | augusta
# Processing Record 10 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 23 | whitianga
# Processing Record 12 of Set 23 | panama city
# Processing Record 13 of Set 23 | san francisco
# Processing Record 14 of Set 23 | arman
# Processing Record 15 of Set 23 | qostanay
# Processing Record 16 of Set 23 | hoa binh
# Processing Record 17 of Set 23 | vung tau
# Processing Record 18 of Set 23 | porto novo
# Processing Record 19 of Set 23 | niteroi
# Processing Record 20 of Set 23 | bud
# Processing Record 21 of Set 23 | cabo san lucas
# Processing Record 22 of Set 23 | henties bay
# Processing Record 23 of Set 23 | chom bung
# City not found. Skipping...
# Processing Record 24 of Set 23 | kodinsk
# Processing Record 25 of Set 23 | san
# Processing Record 26 of Set 23 | jieshi
# Processing Record 27 of Set 23 | tual
# Processing Record 28 of Set 23 | north bend
# Processing Record 29 of Set 23 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 23 | kununurra
# Processing Record 31 of Set 23 | mackay
# Processing Record 32 of Set 23 | havelock
# Processing Record 33 of Set 23 | colon
# Processing Record 34 of Set 23 | nampula
# Processing Record 35 of Set 23 | kollumerland
# City not found. Skipping...
# Processing Record 36 of Set 23 | udachnyy
# Processing Record 37 of Set 23 | marsa matruh
# Processing Record 38 of Set 23 | lazaro cardenas
# Processing Record 39 of Set 23 | alyangula
# Processing Record 40 of Set 23 | kumanovo
# Processing Record 41 of Set 23 | college
# Processing Record 42 of Set 23 | buncrana
# Processing Record 43 of Set 23 | massaguet
# Processing Record 44 of Set 23 | nago
# Processing Record 45 of Set 23 | manokwari
# Processing Record 46 of Set 23 | chuguyevka
# Processing Record 47 of Set 23 | treinta y tres
# Processing Record 48 of Set 23 | saint-pierre
# Processing Record 49 of Set 23 | norman wells
# Processing Record 50 of Set 23 | tevaitoa
# Processing Record 1 of Set 24 | lubao
# Processing Record 2 of Set 24 | richards bay
# Processing Record 3 of Set 24 | las vegas
# Processing Record 4 of Set 24 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 24 | ponta delgada
# Processing Record 6 of Set 24 | makokou
# Processing Record 7 of Set 24 | montevideo
# Processing Record 8 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 24 | tura
# Processing Record 10 of Set 24 | buala
# Processing Record 11 of Set 24 | hammerfest
# Processing Record 12 of Set 24 | macherla
# Processing Record 13 of Set 24 | belur
# Processing Record 14 of Set 24 | pachino
# Processing Record 15 of Set 24 | crotone
# Processing Record 16 of Set 24 | sarangani
# Processing Record 17 of Set 24 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 24 | ranibennur
# Processing Record 19 of Set 24 | kourou
# Processing Record 20 of Set 24 | rio bueno
# Processing Record 21 of Set 24 | casselman
# Processing Record 22 of Set 24 | novikovo
# Processing Record 23 of Set 24 | yar-sale
# Processing Record 24 of Set 24 | aloja
# Processing Record 25 of Set 24 | gigmoto
# Processing Record 26 of Set 24 | atar
# Processing Record 27 of Set 24 | kandrian
# Processing Record 28 of Set 24 | xichang
# Processing Record 29 of Set 24 | esmeraldas
# Processing Record 30 of Set 24 | kondagaon
# Processing Record 31 of Set 24 | sagae
# Processing Record 32 of Set 24 | phu ly
# Processing Record 33 of Set 24 | opuwo
# Processing Record 34 of Set 24 | moron
# Processing Record 35 of Set 24 | muros
# Processing Record 36 of Set 24 | camacha
# Processing Record 37 of Set 24 | victoria
# Processing Record 38 of Set 24 | slave lake
# Processing Record 39 of Set 24 | aranos
# Processing Record 40 of Set 24 | abong mbang
# Processing Record 41 of Set 24 | sao joao da barra
# Processing Record 42 of Set 24 | yerbogachen
# Processing Record 43 of Set 24 | puerto montt
# Processing Record 44 of Set 24 | ranong
# Processing Record 45 of Set 24 | bone
# Processing Record 46 of Set 24 | gizo
# Processing Record 47 of Set 24 | edd
# Processing Record 48 of Set 24 | pacific grove
# Processing Record 49 of Set 24 | nyurba
# Processing Record 50 of Set 24 | whyalla
# Processing Record 1 of Set 25 | namatanai
# Processing Record 2 of Set 25 | manggar
# Processing Record 3 of Set 25 | kingman
# Processing Record 4 of Set 25 | koumac
# Processing Record 5 of Set 25 | nalut
# Processing Record 6 of Set 25 | sao miguel do araguaia
# Processing Record 7 of Set 25 | ancud
# Processing Record 8 of Set 25 | puerto leguizamo
# Processing Record 9 of Set 25 | nerchinskiy zavod
# Processing Record 10 of Set 25 | sindor
# Processing Record 11 of Set 25 | laramie
# Processing Record 12 of Set 25 | mount isa
# Processing Record 13 of Set 25 | coihaique
# Processing Record 14 of Set 25 | rio muerto
# Processing Record 15 of Set 25 | zhangye
# Processing Record 16 of Set 25 | nabire
# Processing Record 17 of Set 25 | surt
# Processing Record 18 of Set 25 | kondinskoye
# Processing Record 19 of Set 25 | alto araguaia
# Processing Record 20 of Set 25 | opelousas
# Processing Record 21 of Set 25 | bathsheba
# Processing Record 22 of Set 25 | kaili
# Processing Record 23 of Set 25 | salinopolis
# Processing Record 24 of Set 25 | zinder
# Processing Record 25 of Set 25 | mogadishu
# Processing Record 26 of Set 25 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 25 | payo
# Processing Record 28 of Set 25 | sambava
# Processing Record 29 of Set 25 | westport
# Processing Record 30 of Set 25 | viedma
# Processing Record 31 of Set 25 | srednekolymsk
# Processing Record 32 of Set 25 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 25 | touros
# Processing Record 34 of Set 25 | komsomolskiy
# Processing Record 35 of Set 25 | boissevain
# Processing Record 36 of Set 25 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 25 | kentau
# Processing Record 38 of Set 25 | zhanaozen
# Processing Record 39 of Set 25 | faya
# Processing Record 40 of Set 25 | flores
# Processing Record 41 of Set 25 | bonfim
# Processing Record 42 of Set 25 | pangnirtung
# Processing Record 43 of Set 25 | tiznit
# Processing Record 44 of Set 25 | yialos
# City not found. Skipping...
# Processing Record 45 of Set 25 | axim
# Processing Record 46 of Set 25 | kavieng
# Processing Record 47 of Set 25 | christchurch
# Processing Record 48 of Set 25 | debre birhan
# Processing Record 49 of Set 25 | takahashi
# Processing Record 50 of Set 25 | ust-nera
# Processing Record 1 of Set 26 | kaeo
# Processing Record 2 of Set 26 | lompoc
# Processing Record 3 of Set 26 | chipinge
# Processing Record 4 of Set 26 | bonthe
# Processing Record 5 of Set 26 | batagay
# Processing Record 6 of Set 26 | ribeira brava
# Processing Record 7 of Set 26 | leninsk-kuznetskiy
# Processing Record 8 of Set 26 | lasa
# Processing Record 9 of Set 26 | saint-georges
# Processing Record 10 of Set 26 | grindavik
# Processing Record 11 of Set 26 | maniitsoq
# Processing Record 12 of Set 26 | mayskiy
# Processing Record 13 of Set 26 | mulanje
# Processing Record 14 of Set 26 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 26 | zavetnoye
# Processing Record 16 of Set 26 | surgut
# Processing Record 17 of Set 26 | bandarbeyla
# Processing Record 18 of Set 26 | adrar
# Processing Record 19 of Set 26 | poum
# Processing Record 20 of Set 26 | tateyama
# Processing Record 21 of Set 26 | altonia
# City not found. Skipping...
# Processing Record 22 of Set 26 | bilma
# Processing Record 23 of Set 26 | tarakan
# Processing Record 24 of Set 26 | sangmelima
# Processing Record 25 of Set 26 | gouyave
# Processing Record 26 of Set 26 | varkaus
# Processing Record 27 of Set 26 | gambela
# Processing Record 28 of Set 26 | kerema
# Processing Record 29 of Set 26 | port-gentil
# Processing Record 30 of Set 26 | tucumcari
# Processing Record 31 of Set 26 | betare oya
# Processing Record 32 of Set 26 | talesh
# City not found. Skipping...
# Processing Record 33 of Set 26 | ust-omchug
# Processing Record 34 of Set 26 | scottsbluff
# Processing Record 35 of Set 26 | charlestown
# Processing Record 36 of Set 26 | feltre
# Processing Record 37 of Set 26 | portage
# Processing Record 38 of Set 26 | standerton
# Processing Record 39 of Set 26 | carbondale
# Processing Record 40 of Set 26 | chara
# Processing Record 41 of Set 26 | halifax
# Processing Record 42 of Set 26 | nome
# Processing Record 43 of Set 26 | paka
# Processing Record 44 of Set 26 | casper
# Processing Record 45 of Set 26 | akyab
# Processing Record 46 of Set 26 | barcelos
# Processing Record 47 of Set 26 | dryden
# Processing Record 48 of Set 26 | birao
# Processing Record 49 of Set 26 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 26 | altay
# Processing Record 1 of Set 27 | pringsewu
# Processing Record 2 of Set 27 | sakakah
# Processing Record 3 of Set 27 | llanes
# Processing Record 4 of Set 27 | san policarpo
# Processing Record 5 of Set 27 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 27 | abnub
# Processing Record 7 of Set 27 | vakhrushev
# Processing Record 8 of Set 27 | kaitangata
# Processing Record 9 of Set 27 | zyryanka
# Processing Record 10 of Set 27 | wamba
# Processing Record 11 of Set 27 | gayeri
# Processing Record 12 of Set 27 | pisco
# Processing Record 13 of Set 27 | merta
# Processing Record 14 of Set 27 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 27 | bell ville
# Processing Record 16 of Set 27 | ulladulla
# Processing Record 17 of Set 27 | isangel
# Processing Record 18 of Set 27 | vila velha
# Processing Record 19 of Set 27 | perth
# Processing Record 20 of Set 27 | novodugino
# Processing Record 21 of Set 27 | sungaipenuh
# Processing Record 22 of Set 27 | khvoynaya
# Processing Record 23 of Set 27 | chapais
# Processing Record 24 of Set 27 | hay river
# Processing Record 25 of Set 27 | monrovia
# Processing Record 26 of Set 27 | jumla
# Processing Record 27 of Set 27 | manjacaze
# Processing Record 28 of Set 27 | khandyga
# Processing Record 29 of Set 27 | larsnes
# Processing Record 30 of Set 27 | banes
# Processing Record 31 of Set 27 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 27 | channel-port aux basques
# Processing Record 33 of Set 27 | anaconda
# Processing Record 34 of Set 27 | olutanga
# Processing Record 35 of Set 27 | pemangkat
# Processing Record 36 of Set 27 | sumbawanga
# Processing Record 37 of Set 27 | kaoma
# Processing Record 38 of Set 27 | kapuskasing
# Processing Record 39 of Set 27 | atambua
# Processing Record 40 of Set 27 | samarai
# Processing Record 41 of Set 27 | mexico
# Processing Record 42 of Set 27 | hambantota
# Processing Record 43 of Set 27 | natchez
# Processing Record 44 of Set 27 | vrangel
# Processing Record 45 of Set 27 | flin flon
# Processing Record 46 of Set 27 | alice springs
# Processing Record 47 of Set 27 | dukat
# Processing Record 48 of Set 27 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 27 | myskhako
# Processing Record 50 of Set 27 | valdivia
# Processing Record 1 of Set 28 | general teran
# Processing Record 2 of Set 28 | okha
# Processing Record 3 of Set 28 | capreol
# Processing Record 4 of Set 28 | lufilufi
# Processing Record 5 of Set 28 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 28 | redlands
# Processing Record 7 of Set 28 | bibbiena
# Processing Record 8 of Set 28 | general roca
# Processing Record 9 of Set 28 | pillaro
# Processing Record 10 of Set 28 | saint george
# Processing Record 11 of Set 28 | kiunga
# Processing Record 12 of Set 28 | coahuayana
# Processing Record 13 of Set 28 | marsh harbour
# Processing Record 14 of Set 28 | bouna
# Processing Record 15 of Set 28 | luancheng
# Processing Record 16 of Set 28 | sabang
# Processing Record 17 of Set 28 | mersing
# Processing Record 18 of Set 28 | panjab
# Processing Record 19 of Set 28 | goure
# Processing Record 20 of Set 28 | poltavka
# Processing Record 21 of Set 28 | carmelo
# Processing Record 22 of Set 28 | shelburne
# Processing Record 23 of Set 28 | maceio
# Processing Record 24 of Set 28 | lander
# Processing Record 25 of Set 28 | marawi
# Processing Record 26 of Set 28 | naze
# Processing Record 27 of Set 28 | ourossogui
# Processing Record 28 of Set 28 | athabasca
# Processing Record 29 of Set 28 | yarada
# Processing Record 30 of Set 28 | ewa beach
# Processing Record 31 of Set 28 | wazzan
# City not found. Skipping...
# Processing Record 32 of Set 28 | chokwe
# Processing Record 33 of Set 28 | fort wayne
# Processing Record 34 of Set 28 | calamar
# Processing Record 35 of Set 28 | port lincoln
# Processing Record 36 of Set 28 | muromtsevo
# Processing Record 37 of Set 28 | portmore
# Processing Record 38 of Set 28 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 28 | itarema
# Processing Record 40 of Set 28 | wawina
# Processing Record 41 of Set 28 | vostok
# Processing Record 42 of Set 28 | ayan
# Processing Record 43 of Set 28 | yagodnoye
# Processing Record 44 of Set 28 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 28 | lincoln
# Processing Record 46 of Set 28 | chernyshevskiy
# Processing Record 47 of Set 28 | wum
# Processing Record 48 of Set 28 | oussouye
# Processing Record 49 of Set 28 | bisceglie
# Processing Record 50 of Set 28 | agadir
# Processing Record 1 of Set 29 | aksarka
# Processing Record 2 of Set 29 | tibacuy
# Processing Record 3 of Set 29 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 29 | grand gaube
# Processing Record 5 of Set 29 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 29 | san blas
# Processing Record 7 of Set 29 | riyadh
# Processing Record 8 of Set 29 | can tho
# Processing Record 9 of Set 29 | west bay
# Processing Record 10 of Set 29 | maria la baja
# Processing Record 11 of Set 29 | pechora
# Processing Record 12 of Set 29 | am timan
# Processing Record 13 of Set 29 | redmond
# Processing Record 14 of Set 29 | sergeyevka
# Processing Record 15 of Set 29 | eyl
# Processing Record 16 of Set 29 | sarapul
# Processing Record 17 of Set 29 | george town
# Processing Record 18 of Set 29 | oranjemund
# Processing Record 19 of Set 29 | umm jarr
# City not found. Skipping...
# Processing Record 20 of Set 29 | kommunisticheskiy
# Processing Record 21 of Set 29 | aykhal
# Processing Record 22 of Set 29 | culaba
# Processing Record 23 of Set 29 | mola di bari
# Processing Record 24 of Set 29 | guanhaes
# Processing Record 25 of Set 29 | stawell
# Processing Record 26 of Set 29 | el balyana
# City not found. Skipping...
# Processing Record 27 of Set 29 | pingliang
# Processing Record 28 of Set 29 | bull savanna
# Processing Record 29 of Set 29 | zabid
# Processing Record 30 of Set 29 | minot
# Processing Record 31 of Set 29 | toora-khem
# Processing Record 32 of Set 29 | harbour breton
# Processing Record 33 of Set 29 | vysokogornyy
# Processing Record 34 of Set 29 | agadez
# Processing Record 35 of Set 29 | lysyanka
# Processing Record 36 of Set 29 | mojo
# Processing Record 37 of Set 29 | ghanzi
# Processing Record 38 of Set 29 | mayor pablo lagerenza
# Processing Record 39 of Set 29 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 29 | higuey
# City not found. Skipping...
# Processing Record 41 of Set 29 | celestun
# Processing Record 42 of Set 29 | nishihara
# Processing Record 43 of Set 29 | el alto
# Processing Record 44 of Set 29 | owando
# Processing Record 45 of Set 29 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 29 | xiamen
# Processing Record 47 of Set 29 | rongcheng
# Processing Record 48 of Set 29 | yankton
# Processing Record 49 of Set 29 | pinawa
# Processing Record 50 of Set 29 | uni
# Processing Record 1 of Set 30 | itoman
# Processing Record 2 of Set 30 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 30 | nagato
# Processing Record 4 of Set 30 | kendal
# Processing Record 5 of Set 30 | cap malheureux
# Processing Record 6 of Set 30 | lakes entrance
# Processing Record 7 of Set 30 | straseni
# Processing Record 8 of Set 30 | dayong
# Processing Record 9 of Set 30 | san cristobal
# Processing Record 10 of Set 30 | stykkisholmur
# Processing Record 11 of Set 30 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 30 | lima
# Processing Record 13 of Set 30 | dong hoi
# Processing Record 14 of Set 30 | ilulissat
# Processing Record 15 of Set 30 | freeport
# Processing Record 16 of Set 30 | nhulunbuy
# Processing Record 17 of Set 30 | hersbruck
# Processing Record 18 of Set 30 | kindu
# Processing Record 19 of Set 30 | sao gabriel da cachoeira
# Processing Record 20 of Set 30 | murree
# Processing Record 21 of Set 30 | abha
# Processing Record 22 of Set 30 | luwuk
# Processing Record 23 of Set 30 | horsham
# Processing Record 24 of Set 30 | chone
# Processing Record 25 of Set 30 | aurillac
# Processing Record 26 of Set 30 | ambikapur
# Processing Record 27 of Set 30 | ambunti
# Processing Record 28 of Set 30 | salumbar
# Processing Record 29 of Set 30 | arona
# Processing Record 30 of Set 30 | kangaba
# Processing Record 31 of Set 30 | bonavista
# Processing Record 32 of Set 30 | bay roberts
# Processing Record 33 of Set 30 | joshimath
# Processing Record 34 of Set 30 | benguela
# Processing Record 35 of Set 30 | puerto madero
# Processing Record 36 of Set 30 | necochea
# Processing Record 37 of Set 30 | yerofey pavlovich
# Processing Record 38 of Set 30 | berlevag
# Processing Record 39 of Set 30 | chenzhou
# Processing Record 40 of Set 30 | zhangjiakou
# Processing Record 41 of Set 30 | bouake
# Processing Record 42 of Set 30 | leon valley
# Processing Record 43 of Set 30 | villa guerrero
# Processing Record 44 of Set 30 | nara
# Processing Record 45 of Set 30 | nurota
# Processing Record 46 of Set 30 | bac lieu
# Processing Record 47 of Set 30 | jalesar
# Processing Record 48 of Set 30 | tabuk
# Processing Record 49 of Set 30 | cockburn town
# Processing Record 50 of Set 30 | chaa-khol
# City not found. Skipping...
# Processing Record 1 of Set 31 | de aar
# Processing Record 2 of Set 31 | lensk
# Processing Record 3 of Set 31 | suzu
# City not found. Skipping...
# Processing Record 4 of Set 31 | tautira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
# reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
#"Current Description"
city_data_new_column_order_df = city_data_df[new_column_order]

city_data_new_column_order_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Barrow      US  71.29 -156.79     41.00        75          90
# 1         Bulgan      MN  48.81  103.53     53.19        84         100
# 2      Jamestown      US  42.10  -79.24     72.00        83          90
# 3         Laredo      US  27.51  -99.51     96.80        37          75
# 4          Kapaa      US  22.08 -159.32     82.40        65          90
# 5   Porto Walter      BR  -8.27  -72.74     87.19        40           0
# 6   Punta Arenas      CL -53.15  -70.92     39.20        80          24
# 7         Omboue      GA  -1.57    9.26     73.27        73          70
# 8  Prince Rupert      CA  54.32 -130.32     59.00        93          90
# 9       Hermanus      ZA -34.42   19.23     48.00        96           0
#
#    Wind Speed Current Description
# 0       12.75     overcast clouds
# 1        3.96     overcast clouds
# 2       17.22          light rain
# 3        4.70       broken clouds
# 4       14.99     overcast clouds
# 5        1.07           clear sky
# 6        9.17          few clouds
# 7        6.49       broken clouds
# 8        2.24          light rain
# 9        5.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_new_column_order_df.to_csv(output_data_file, index_label="City_ID")
